# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import seaborn as sns
import matplotlib.colors as mcolors
from mpl_toolkits import mplot3d

# %%
#Checking a sample file
F=pd.read_csv("/home/vikmachine/Desktop/research/Train/Data1.csv")
#Dropping an unnecessary column
F=F.drop('Unnamed: 0',axis=1)
#Checking the sample data
F
# Out:
#        trial number sensor position  sample num  sensor value  \
# 0                 0             FP1           0        -8.921
# 1                 0             FP1           1        -8.433
# 2                 0             FP1           2        -2.574
# 3                 0             FP1           3         5.239
# 4                 0             FP1           4        11.587
# 5                 0             FP1           5        14.028
# 6                 0             FP1           6        11.587
# 7                 0             FP1           7         6.704
# 8                 0             FP1           8         1.821
# 9                 0             FP1           9        -1.109
# 10                0             FP1          10        -2.085
# 11                0             FP1          11        -1.597
# 12                0             FP1          12         0.356
# 13                0             FP1          13         2.309
# 14                0             FP1          14         2.797
# 15                0             FP1          15         2.309
# 16                0             FP1          16         0.356
# 17                0             FP1          17        -0.132
# 18                0             FP1          18        -0.132
# 19                0             FP1          19         0.356
# 20                0             FP1          20         0.844
# 21                0             FP1          21         1.333
# 22                0             FP1          22         2.797
# 23                0             FP1          23         6.215
# 24                0             FP1          24         9.633
# 25                0             FP1          25        10.610
# 26                0             FP1          26         6.704
# 27                0             FP1          27        -0.621
# 28                0             FP1          28        -5.992
# 29                0             FP1          29        -6.480
# ...             ...             ...         ...           ...
# 16354             0               Y         226        15.361
# 16355             0               Y         227        19.755
# 16356             0               Y         228        21.708
# 16357             0               Y         229        20.243
# 16358             0               Y         230        15.361
# 16359             0               Y         231        11.943
# 16360             0               Y         232        12.919
# 16361             0               Y         233        17.314
# 16362             0               Y         234        21.220
# 16363             0               Y         235        22.196
# 16364             0               Y         236        20.732
# 16365             0               Y         237        18.290
# 16366             0               Y         238        17.802
# 16367             0               Y         239        17.802
# 16368             0               Y         240        17.314
# 16369             0               Y         241        14.872
# 16370             0               Y         242        12.431
# 16371             0               Y         243        13.407
# 16372             0               Y         244        17.802
# 16373             0               Y         245        23.173
# 16374             0               Y         246        24.150
# 16375             0               Y         247        20.243
# 16376             0               Y         248        11.454
# 16377             0               Y         249         4.618
# 16378             0               Y         250         3.153
# 16379             0               Y         251         6.571
# 16380             0               Y         252        12.431
# 16381             0               Y         253        15.849
# 16382             0               Y         254        16.337
# 16383             0               Y         255        14.872
#
#       subject identifier matching condition  channel         name      time
# 0                      a             S1 obj        0  co2a0000364  0.000000
# 1                      a             S1 obj        0  co2a0000364  0.003906
# 2                      a             S1 obj        0  co2a0000364  0.007812
# 3                      a             S1 obj        0  co2a0000364  0.011719
# 4                      a             S1 obj        0  co2a0000364  0.015625
# 5                      a             S1 obj        0  co2a0000364  0.019531
# 6                      a             S1 obj        0  co2a0000364  0.023438
# 7                      a             S1 obj        0  co2a0000364  0.027344
# 8                      a             S1 obj        0  co2a0000364  0.031250
# 9                      a             S1 obj        0  co2a0000364  0.035156
# 10                     a             S1 obj        0  co2a0000364  0.039062
# 11                     a             S1 obj        0  co2a0000364  0.042969
# 12                     a             S1 obj        0  co2a0000364  0.046875
# 13                     a             S1 obj        0  co2a0000364  0.050781
# 14                     a             S1 obj        0  co2a0000364  0.054688
# 15                     a             S1 obj        0  co2a0000364  0.058594
# 16                     a             S1 obj        0  co2a0000364  0.062500
# 17                     a             S1 obj        0  co2a0000364  0.066406
# 18                     a             S1 obj        0  co2a0000364  0.070312
# 19                     a             S1 obj        0  co2a0000364  0.074219
# 20                     a             S1 obj        0  co2a0000364  0.078125
# 21                     a             S1 obj        0  co2a0000364  0.082031
# 22                     a             S1 obj        0  co2a0000364  0.085938
# 23                     a             S1 obj        0  co2a0000364  0.089844
# 24                     a             S1 obj        0  co2a0000364  0.093750
# 25                     a             S1 obj        0  co2a0000364  0.097656
# 26                     a             S1 obj        0  co2a0000364  0.101562
# 27                     a             S1 obj        0  co2a0000364  0.105469
# 28                     a             S1 obj        0  co2a0000364  0.109375
# 29                     a             S1 obj        0  co2a0000364  0.113281
# ...                  ...                ...      ...          ...       ...
# 16354                  a             S1 obj       63  co2a0000364  0.882812
# 16355                  a             S1 obj       63  co2a0000364  0.886719
# 16356                  a             S1 obj       63  co2a0000364  0.890625
# 16357                  a             S1 obj       63  co2a0000364  0.894531
# 16358                  a             S1 obj       63  co2a0000364  0.898438
# 16359                  a             S1 obj       63  co2a0000364  0.902344
# 16360                  a             S1 obj       63  co2a0000364  0.906250
# 16361                  a             S1 obj       63  co2a0000364  0.910156
# 16362                  a             S1 obj       63  co2a0000364  0.914062
# 16363                  a             S1 obj       63  co2a0000364  0.917969
# 16364                  a             S1 obj       63  co2a0000364  0.921875
# 16365                  a             S1 obj       63  co2a0000364  0.925781
# 16366                  a             S1 obj       63  co2a0000364  0.929688
# 16367                  a             S1 obj       63  co2a0000364  0.933594
# 16368                  a             S1 obj       63  co2a0000364  0.937500
# 16369                  a             S1 obj       63  co2a0000364  0.941406
# 16370                  a             S1 obj       63  co2a0000364  0.945312
# 16371                  a             S1 obj       63  co2a0000364  0.949219
# 16372                  a             S1 obj       63  co2a0000364  0.953125
# 16373                  a             S1 obj       63  co2a0000364  0.957031
# 16374                  a             S1 obj       63  co2a0000364  0.960938
# 16375                  a             S1 obj       63  co2a0000364  0.964844
# 16376                  a             S1 obj       63  co2a0000364  0.968750
# 16377                  a             S1 obj       63  co2a0000364  0.972656
# 16378                  a             S1 obj       63  co2a0000364  0.976562
# 16379                  a             S1 obj       63  co2a0000364  0.980469
# 16380                  a             S1 obj       63  co2a0000364  0.984375
# 16381                  a             S1 obj       63  co2a0000364  0.988281
# 16382                  a             S1 obj       63  co2a0000364  0.992188
# 16383                  a             S1 obj       63  co2a0000364  0.996094
#
# [16384 rows x 9 columns]

# %%
F.describe()
# Out:
#        trial number    sample num  sensor value       channel          time
# count       16384.0  16384.000000  16384.000000  16384.000000  16384.000000
# mean            0.0    127.500000      1.989997     31.500000      0.498047
# std             0.0     73.902526      7.505248     18.473517      0.288682
# min             0.0      0.000000    -39.825000      0.000000      0.000000
# 25%             0.0     63.750000     -2.228000     15.750000      0.249023
# 50%             0.0    127.500000      1.221000     31.500000      0.498047
# 75%             0.0    191.250000      5.402000     47.250000      0.747070
# max             0.0    255.000000     51.900000     63.000000      0.996094

# %%
F.info()

# %%
n=0
for i in range(238,239):
    F=pd.read_csv("/home/vikmachine/Desktop/research/Train/Data"+str(i)+".csv")
    F['matching condition']= F['matching condition'].astype(str)
    F['subject identifier']= F['subject identifier'].astype(str)
    if F.loc[5,'matching condition']=='S1 obj' and F.loc[5,'subject identifier']=='c':
        n=n+1
        if n==1:
            Z2= F
        else: 
            Z2 = Z2.append(F)
print("Done")

#X1=Z[['channel','sensor value']].groupby('channel',as_index=False).mean().sort_values(by='channel',ascending=True)
X3=Z2[['channel','sensor value','time']].sort_values(by='channel',ascending=True)
s,ax=plt.subplots(figsize=(14,9))
ax = plt.axes(projection='3d')
ax.plot_trisurf(X3['channel'],X3['time'], X3['sensor value'], cmap=cm.jet, linewidth=0.2)
#ax.plot_surface(X2['channel'], X2['sensor value'], X2['time'], rstride=1, cstride=1, edgecolor='none')
ax.set_xlabel('Channel')
ax.set_ylabel('time')
ax.set_zlabel('sensor value')
ax.set_title('average non-alcoholic for S1 object')
plt.show()


n=0  
for i in range(1,2):
    F=pd.read_csv("/home/vikmachine/Desktop/research/Train/Data"+str(i)+".csv")
    F['matching condition']= F['matching condition'].astype(str)
    F['subject identifier']= F['subject identifier'].astype(str)
    if F.loc[5,'matching condition']=='S1 obj' and F.loc[5,'subject identifier']=='a':
        n=n+1
        if n==1:
            Z1= F
        else: 
            Z1 = Z1.append(F)
print("Done")
#X1=Z[['channel','sensor value']].groupby('channel',as_index=False).mean().sort_values(by='channel',ascending=True)
X2=Z1[['channel','sensor value','time']].sort_values(by='channel',ascending=True)
s,ax=plt.subplots(figsize=(14,9))
ax = plt.axes(projection='3d')
ax.plot_trisurf(X2['channel'],X2['time'], X2['sensor value'], cmap=cm.jet, linewidth=0.2)
#ax.plot_surface(X2['channel'], X2['sensor value'], X2['time'], rstride=1, cstride=1, edgecolor='none')
ax.set_xlabel('Channel')
ax.set_ylabel('time')
ax.set_zlabel('sensor value')
ax.set_title('average alcoholic for S1 object')
plt.show()
# Out:
# Done
# Done

# %%
#_____________________________________________________________________________________________________________

n=0 
for i in range(240,241):
    F=pd.read_csv("/home/vikmachine/Desktop/research/Train/Data"+str(i)+".csv")
    F['matching condition']= F['matching condition'].astype(str)
    F['subject identifier']= F['subject identifier'].astype(str)
    if F.loc[5,'matching condition']=='S2 nomatch' and F.loc[5,'subject identifier']=='c':
        n=n+1
        if n==1:
            Z2= F
        else: 
            Z2 = Z2.append(F)
print("Done")

#X1=Z[['channel','sensor value']].groupby('channel',as_index=False).mean().sort_values(by='channel',ascending=True)
X3=Z2[['channel','sensor value','time']].sort_values(by='channel',ascending=True)
s,ax=plt.subplots(figsize=(14,9))
ax = plt.axes(projection='3d')
ax.plot_trisurf(X3['channel'],X3['time'], X3['sensor value'], cmap=cm.jet, linewidth=0.2)
#ax.plot_surface(X2['channel'], X2['sensor value'], X2['time'], rstride=1, cstride=1, edgecolor='none')
ax.set_xlabel('Channel')
ax.set_ylabel('time')
ax.set_zlabel('sensor value')
ax.set_title('average non-alcoholic S2 nomatch')
plt.show()

n=0  
for i in range(3,4):
    F=pd.read_csv("/home/vikmachine/Desktop/research/Train/Data"+str(i)+".csv")
    F['matching condition']= F['matching condition'].astype(str)
    F['subject identifier']= F['subject identifier'].astype(str)
    if F.loc[5,'matching condition']=='S2 nomatch' and F.loc[5,'subject identifier']=='a':
        n=n+1
        if n==1:
            Z1= F
        else: 
            Z1 = Z1.append(F)
print("Done")
#X1=Z[['channel','sensor value']].groupby('channel',as_index=False).mean().sort_values(by='channel',ascending=True)
X2=Z1[['channel','sensor value','time']].sort_values(by='channel',ascending=True)
s,ax=plt.subplots(figsize=(14,9))
ax = plt.axes(projection='3d')
ax.plot_trisurf(X2['channel'],X2['time'], X2['sensor value'], cmap=cm.jet, linewidth=0.2)
#ax.plot_surface(X2['channel'], X2['sensor value'], X2['time'], rstride=1, cstride=1, edgecolor='none')
ax.set_xlabel('Channel')
ax.set_ylabel('time')
ax.set_zlabel('sensor value')
ax.set_title('average alcoholic for S2 nomatch')
plt.show()
# Out:
# Done
# Done

# %%
n=0 
for i in range(317,318):
    F=pd.read_csv("/home/vikmachine/Desktop/research/Train/Data"+str(i)+".csv")
    F['matching condition']= F['matching condition'].astype(str)
    F['subject identifier']= F['subject identifier'].astype(str)
    if F.loc[5,'matching condition']=='S2 match' and F.loc[5,'subject identifier']=='c':
        n=n+1
        if n==1:
            Z2= F
        else: 
            Z2 = Z2.append(F)
print("Done")

#X1=Z[['channel','sensor value']].groupby('channel',as_index=False).mean().sort_values(by='channel',ascending=True)
X3=Z2[['channel','sensor value','time']].sort_values(by='channel',ascending=True)
s,ax=plt.subplots(figsize=(14,9))
ax = plt.axes(projection='3d')
ax.plot_trisurf(X3['channel'],X3['time'], X3['sensor value'], cmap=cm.jet, linewidth=0.2)
#ax.plot_surface(X2['channel'], X2['sensor value'], X2['time'], rstride=1, cstride=1, edgecolor='none')
ax.set_xlabel('Channel')
ax.set_ylabel('time')
ax.set_zlabel('sensor value')
ax.set_title('average non-alcoholic S2 match')
plt.show()

n=0  
for i in range(4,5):
    F=pd.read_csv("/home/vikmachine/Desktop/research/Train/Data"+str(i)+".csv")
    F['matching condition']= F['matching condition'].astype(str)
    F['subject identifier']= F['subject identifier'].astype(str)
    if F.loc[5,'matching condition']=='S2 match' and F.loc[5,'subject identifier']=='a':
        n=n+1
        if n==1:
            Z1= F
        else: 
            Z1 = Z1.append(F)
print("Done")
#X1=Z[['channel','sensor value']].groupby('channel',as_index=False).mean().sort_values(by='channel',ascending=True)
X2=Z1[['channel','sensor value','time']].sort_values(by='channel',ascending=True)
s,ax=plt.subplots(figsize=(14,9))
ax = plt.axes(projection='3d')
ax.plot_trisurf(X2['channel'],X2['time'], X2['sensor value'], cmap=cm.jet, linewidth=0.2)
#ax.plot_surface(X2['channel'], X2['sensor value'], X2['time'], rstride=1, cstride=1, edgecolor='none')
ax.set_xlabel('Channel')
ax.set_ylabel('time')
ax.set_zlabel('sensor value')
ax.set_title('average alcoholic for S2 match')
plt.show()
# Out:
# Done
# Done

# %%
n=0
for i in range(1,450):
    F=pd.read_csv("/home/vikmachine/Desktop/research/Train/Data"+str(i)+".csv")
    F['matching condition']= F['matching condition'].astype(str)
    F['subject identifier']= F['subject identifier'].astype(str)
    if F.loc[1,'matching condition']=='S1 obj' and F.loc[1,'subject identifier']=='c':
        n=n+1
        if n==1:
            Z= F
        else: 
            Z = Z.append(F)
n=0            
for i in range(1,450):
    F=pd.read_csv("/home/vikmachine/Desktop/research/Train/Data"+str(i)+".csv")
    F['matching condition']= F['matching condition'].astype(str)
    F['subject identifier']= F['subject identifier'].astype(str)
    if F.loc[5,'matching condition']=='S1 obj' and F.loc[5,'subject identifier']=='c':
        n=n+1
        if n==1:
            Z1= F
        else: 
            Z1 = Z1.append(F)
print("Done")
X1=Z[['channel','sensor value']].groupby('channel',as_index=False).mean().sort_values(by='channel',ascending=True)
X2=Z1[['channel','sensor value','time']].groupby('channel',as_index=False).mean().sort_values(by='channel',ascending=True)
s,ax=plt.subplots(figsize=(14,5))
sns.lineplot(x='channel',y='sensor value',data=X1, label='non-alchoholic')
sns.lineplot(x='channel',y='sensor value',data=X2, label='alchoholic' )
ax.set_title('average of all sensor values of 10 patients for S1 obj')
plt.legend()

n=0
for i in range(1,450):
    F=pd.read_csv("/home/vikmachine/Desktop/research/Train/Data"+str(i)+".csv")
    F['matching condition']= F['matching condition'].astype(str)
    F['subject identifier']= F['subject identifier'].astype(str)
    if F.loc[1,'matching condition']=='S2 nomatch' and F.loc[1,'subject identifier']=='a':
        n=n+1
        if n==1:
            Z= F
        else: 
            Z = Z.append(F)
n=0            
for i in range(1,450):
    F=pd.read_csv("/home/vikmachine/Desktop/research/Train/Data"+str(i)+".csv")
    F['matching condition']= F['matching condition'].astype(str)
    F['subject identifier']= F['subject identifier'].astype(str)
    if F.loc[5,'matching condition']=='S2 nomatch' and F.loc[5,'subject identifier']=='a':
        n=n+1
        if n==1:
            Z1= F
        else: 
            Z1 = Z1.append(F)
print("Done")
X1=Z[['channel','sensor value']].groupby('channel',as_index=False).mean().sort_values(by='channel',ascending=True)
X2=Z1[['channel','sensor value','time']].groupby('channel',as_index=False).mean().sort_values(by='channel',ascending=True)
s,ax=plt.subplots(figsize=(14,5))
sns.lineplot(x='channel',y='sensor value',data=X1, label='non-alchoholic')
sns.lineplot(x='channel',y='sensor value',data=X2, label='alchoholic' )
ax.set_title('average of all sensor values of 10 patients for S1 nomatch')
plt.legend()


for i in range(1,450):
    F=pd.read_csv("/home/vikmachine/Desktop/research/Train/Data"+str(i)+".csv")
    F['matching condition']= F['matching condition'].astype(str)
    F['subject identifier']= F['subject identifier'].astype(str)
    if F.loc[5,'matching condition']=='S2 match' and F.loc[5,'subject identifier']=='a':
        n=n+1
        if n==1:
            Z1= F
        else: 
            Z1 = Z1.append(F)
n=0

for i in range(1,450):
    F=pd.read_csv("/home/vikmachine/Desktop/research/Train/Data"+str(i)+".csv")
    F['matching condition']= F['matching condition'].astype(str)
    F['subject identifier']= F['subject identifier'].astype(str)
    if F.loc[1,'matching condition']=='S2 match' and F.loc[1,'subject identifier']=='c':
        n=n+1
        if n==1:
            Z= F
        else: 
            Z = Z.append(F)
n=0            
print("Done")
X2=Z1[['channel','sensor value','time']].groupby('channel',as_index=False).mean().sort_values(by='channel',ascending=True)
X1=Z[['channel','sensor value']].groupby('channel',as_index=False).mean().sort_values(by='channel',ascending=True)
s,ax=plt.subplots(figsize=(14,5))
sns.lineplot(x='channel',y='sensor value',data=X2, label='non-alchoholic')
sns.lineplot(x='channel',y='sensor value',data=X1, label='alchoholic')
ax.set_title('average of all sensor values of 10 patients for S2 match')
plt.legend()
# Out:
# Done
# Done
# Done
